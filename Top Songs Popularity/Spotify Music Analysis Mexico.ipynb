# %%
# https://developer.spotify.com/console/get-audio-features-several-tracks/?ids=4JpKVNYnVcJ8tuMKjAj50A,2NRANZE9UCmPAS5XVbXL40,24JygzOLM0EmRQeGtFcIcG

#https://www.kaggle.com/aeryan/spotify-music-analysis

#https://www.kaggle.com/cihanoklap/top-songs-on-spotify-what-makes-them-popular

# %%
import pandas as pd
import datetime as dt
from sqlalchemy import create_engine
import requests
import pymongo
import json

# pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
path = "Charts CSV/regional-mx-daily-latest.csv"
spotify_data_global = pd.read_csv(path)
spotify_data_global.head()
# Out:
#   Unnamed: 0            Unnamed: 1      Unnamed: 2  \
# 0   Position            Track Name          Artist
# 1          1            Todo De Ti  Rauw Alejandro
# 2          2              Yonaguni       Bad Bunny
# 3          3         Qué Más Pues?        J Balvin
# 4          4  Botella Tras Botella         Gera MX
#
#   Note that these figures are generated using a formula that protects against any artificial inflation of chart positions.  \
# 0                                                                                                                  Streams
# 1                                                                                                                   952609
# 2                                                                                                                   860476
# 3                                                                                                                   663470
# 4                                                                                                                   601604
#
#                                               Unnamed: 4
# 0                                                    URL
# 1  https://open.spotify.com/track/5RwV8BvLfX5injfqYodke9
# 2  https://open.spotify.com/track/2JPLbjOn0wPCngEot2STUS
# 3  https://open.spotify.com/track/6hf0RpxTbOprT5nnwzkk8e
# 4  https://open.spotify.com/track/2MnLkFqY9Rpg9s3Zv6ZJdK

# %%
spotify_data_global.to_csv("clean_mexico.csv", header=False, index=False)

# %%
path_france_clean = "clean_mexico.csv"
spotify_data_mexico_clean = pd.read_csv(path_france_clean)
spotify_data_mexico_clean.head()
# Out:
#    Position            Track Name          Artist  Streams  \
# 0         1            Todo De Ti  Rauw Alejandro   952609
# 1         2              Yonaguni       Bad Bunny   860476
# 2         3         Qué Más Pues?        J Balvin   663470
# 3         4  Botella Tras Botella         Gera MX   601604
# 4         5              AM Remix      Nio Garcia   596388
#
#                                                      URL
# 0  https://open.spotify.com/track/5RwV8BvLfX5injfqYodke9
# 1  https://open.spotify.com/track/2JPLbjOn0wPCngEot2STUS
# 2  https://open.spotify.com/track/6hf0RpxTbOprT5nnwzkk8e
# 3  https://open.spotify.com/track/2MnLkFqY9Rpg9s3Zv6ZJdK
# 4  https://open.spotify.com/track/05bfbizlM5AX6Mf1RRyMho

# %%
spotify_data_mexico_clean["ID"] = spotify_data_mexico_clean["URL"].str[31:]
spotify_data_mexico_clean.head()
# Out:
#    Position            Track Name          Artist  Streams  \
# 0         1            Todo De Ti  Rauw Alejandro   952609
# 1         2              Yonaguni       Bad Bunny   860476
# 2         3         Qué Más Pues?        J Balvin   663470
# 3         4  Botella Tras Botella         Gera MX   601604
# 4         5              AM Remix      Nio Garcia   596388
#
#                                                      URL  \
# 0  https://open.spotify.com/track/5RwV8BvLfX5injfqYodke9
# 1  https://open.spotify.com/track/2JPLbjOn0wPCngEot2STUS
# 2  https://open.spotify.com/track/6hf0RpxTbOprT5nnwzkk8e
# 3  https://open.spotify.com/track/2MnLkFqY9Rpg9s3Zv6ZJdK
# 4  https://open.spotify.com/track/05bfbizlM5AX6Mf1RRyMho
#
#                        ID
# 0  5RwV8BvLfX5injfqYodke9
# 1  2JPLbjOn0wPCngEot2STUS
# 2  6hf0RpxTbOprT5nnwzkk8e
# 3  2MnLkFqY9Rpg9s3Zv6ZJdK
# 4  05bfbizlM5AX6Mf1RRyMho

# %%
len("https://open.spotify.com/track/")
# Out:
# 31

# %%
test = spotify_data_mexico_clean["URL"].str
print(test[31:])
# Out:
# 0      5RwV8BvLfX5injfqYodke9
# 1      2JPLbjOn0wPCngEot2STUS
# 2      6hf0RpxTbOprT5nnwzkk8e
# 3      2MnLkFqY9Rpg9s3Zv6ZJdK
# 4      05bfbizlM5AX6Mf1RRyMho
#                 ...
# 195    337cEDExdFKmLrQMKjffxr
# 196    6NfrH0ANGmgBXyxgV2PeXt
# 197    0zCOT028cU3DeCqN1G18wE
# 198    0pqnGHJpmpxLKifKRmU6WP
# 199    48XgkAh1fkcZqA2EZWCDX6
# Name: URL, Length: 200, dtype: object

# %%
token = "BQDkUVHSHlnDbARSqmu8syVDQGhqAeZee8NYPICTtocLBkqD3N-h6ziZHUQVFVyi3N6wtI1lKgmlkwKB2nqq0GTkkDTxNkg1GdyrrUkCbe1g9x4UyaCT2vILcmGU5VzIS9QFcMHqFPJ0aqAyNKb1zcRFwwYgzcoUoLdvIdF1xLjQUYcub8Ey7UrahpmoWr5C7zhnkqV0m6Z4T7dmFoIARROaB8AzsxJD2tJHVef24fMmmice1OxfzHedCoi_KaTkTlT9-E5VZHfOKwGuR76T"
headers_dict = {"Authorization": f'Bearer {token}'}

# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define database and collection
db = client.SpotifyTopChartsdb
collection = db.TopMexico
collection.drop()

rows=len(spotify_data_mexico_clean)
global_dict={}
# spotify_artist_dict=[]

for row in range(0,rows):
    # Hacer el llamado a la API de Spotify usando spotify_data_wNA.iloc[row,4]
    artist_id = spotify_data_mexico_clean.iloc[row,5]
    artist_name = spotify_data_mexico_clean.iloc[row,2]
    track_name = spotify_data_mexico_clean.iloc[row,1]

    
    response = requests.get(f'https://api.spotify.com/v1/audio-features?ids={artist_id}', headers=headers_dict).json()
    # print(response)
    # artist_id = response["audio_features"]
    # print(response["audio_features"])

    danceability = response["audio_features"][0]["danceability"]
    energy = response["audio_features"][0]["energy"]
    key = response["audio_features"][0]["liveness"]
    loudness = response["audio_features"][0]["key"]
    acousticness = response["audio_features"][0]["acousticness"]
    instrumentalness = response["audio_features"][0]["instrumentalness"]
    liveness = response["audio_features"][0]["liveness"]
    valence = response["audio_features"][0]["valence"]
    tempo = response["audio_features"][0]["tempo"]
    track_href = response["audio_features"][0]["track_href"]
        
        
    global_dict={'Artist Name':artist_name,
                 'Track Name':track_name,
                 'Danceability': danceability,
                 'Energy': energy,
                 'Key': key,
                 'Loudness': loudness,
                 'Acousticness': acousticness,
                 'Instrumentalness': instrumentalness,
                 'Liveness': liveness,
                 'Valence': valence,
                 'Tempo': tempo,
                 'Track Reference': track_href
                 }
    collection.insert_one(global_dict)
#     spotify_artist_dict.append(artist_dict)
   
    print(global_dict)
# Out:
# {'Artist Name': 'Rauw Alejandro', 'Track Name': 'Todo De Ti', 'Danceability': 0.78, 'Energy': 0.719, 'Key': 0.0931, 'Loudness': 3, 'Acousticness': 0.302, 'Instrumentalness': 0.000196, 'Liveness': 0.0931, 'Valence': 0.336, 'Tempo': 127.962, 'Track Reference': 'https://api.spotify.com/v1/tracks/5RwV8BvLfX5injfqYodke9', '_id': ObjectId('60f790bbe1cf639cfad8a75c')}
# {'Artist Name': 'Bad Bunny', 'Track Name': 'Yonaguni', 'Danceability': 0.644, 'Energy': 0.648, 'Key': 0.135, 'Loudness': 1, 'Acousticness': 0.276, 'Instrumentalness': 0, 'Liveness': 0.135, 'Valence': 0.44, 'Tempo': 179.951, 'Track Reference': 'https://api.spotify.com/v1/tracks/2JPLbjOn0wPCngEot2STUS', '_id': ObjectId('60f790bde1cf639cfad8a75d')}
# {'Artist Name': 'J Balvin', 'Track Name': 'Qué Más Pues?', 'Danceability': 0.891, 'Energy': 0.819, 'Key': 0.173, 'Loudness': 8, 'Acousticness': 0.0261, 'Instrumentalness': 0.000354, 'Liveness': 0.173, 'Valence': 0.768, 'Tempo': 101.968, 'Track Reference': 'https://api.spotify.com/v1/tracks/6hf0RpxTbOprT5nnwzkk8e', '_id': ObjectId('60f790bde1cf639cfad8a75e')}
# {'Artist Name': 'Gera MX', 'Track Name': 'Botella Tras Botella', 'Danceability': 0.727, 'Energy': 0.546, 'Key': 0.122, 'Loudness': 0, 'Acousticness': 0.656, 'Instrumentalness': 0, 'Liveness': 0.122, 'Valence': 0.69, 'Tempo': 106.891, 'Track Reference': 'https://api.spotify.com/v1/tracks/2MnLkFqY9Rpg9s3Zv6ZJdK', '_id': ObjectId('60f790bde1cf639cfad8a75f')}
# {'Artist Name': 'Nio Garcia', 'Track Name': 'AM Remix', 'Danceability': 0.743, 'Energy': 0.655, 'Key': 0.0764, 'Loudness': 6, 'Acousticness': 0.114, 'Instrumentalness': 0, 'Liveness': 0.0764, 'Valence': 0.785, 'Tempo': 172.031, 'Track Reference': 'https://api.spotify.com/v1/tracks/05bfbizlM5AX6Mf1RRyMho', '_id': ObjectId('60f790bee1cf639cfad8a760')}
# {'Artist Name': 'Sebastian Yatra', 'Track Name': 'Pareja Del Año', 'Danceability': 0.715, 'Energy': 0.622, 'Key': 0.0948, 'Loudness': 4, 'Acousticness': 0.163, 'Instrumentalness': 0, 'Liveness': 0.0948, 'Valence': 0.808, 'Tempo': 80.015, 'Track Reference': 'https://api.spotify.com/v1/tracks/2rCbl9naJYhaxjLsfx88uM', '_id': ObjectId('60f790bee1cf639cfad8a761')}
# {'Artist Name': 'Mora', 'Track Name': 'Volando - Remix', 'Danceability': 0.659, 'Energy': 0.688, 'Key': 0.113, 'Loudness': 6, 'Acousticness': 0.207, 'Instrumentalness': 0, 'Liveness': 0.113, 'Valence': 0.632, 'Tempo': 153.979, 'Track Reference': 'https://api.spotify.com/v1/tracks/0G2zPzWqVjR68iNPmx2TBe', '_id': ObjectId('60f790bee1cf639cfad8a762')}
# {'Artist Name': 'Bad Bunny', 'Track Name': 'DÁKITI', 'Danceability': 0.731, 'Energy': 0.573, 'Key': 0.113, 'Loudness': 4, 'Acousticness': 0.401, 'Instrumentalness': 5.22e-05, 'Liveness': 0.113, 'Valence': 0.145, 'Tempo': 109.928, 'Track Reference': 'https://api.spotify.com/v1/tracks/4MzXwWMhyBbmu6hOcLVD49', '_id': ObjectId('60f790bee1cf639cfad8a763')}
# {'Artist Name': 'Måneskin', 'Track Name': "Beggin'", 'Danceability': 0.714, 'Energy': 0.8, 'Key': 0.359, 'Loudness': 11, 'Acousticness': 0.127, 'Instrumentalness': 0, 'Liveness': 0.359, 'Valence': 0.589, 'Tempo': 134.002, 'Track Reference': 'https://api.spotify.com/v1/tracks/3Wrjm47oTz2sjIgck11l5e', '_id': ObjectId('60f790bee1cf639cfad8a764')}
# {'Artist Name': 'Marc Seguí', 'Track Name': 'Tiroteo - Remix', 'Danceability': 0.75, 'Energy': 0.522, 'Key': 0.0743, 'Loudness': 9, 'Acousticness': 0.282, 'Instrumentalness': 0, 'Liveness': 0.0743, 'Valence': 0.601, 'Tempo': 110.427, 'Track Reference': 'https://api.spotify.com/v1/tracks/4OwhwvKESFtuu06dTgct7i', '_id': ObjectId('60f790bfe1cf639cfad8a765')}
# {'Artist Name': 'Los Legendarios', 'Track Name': 'Fiel', 'Danceability': 0.849, 'Energy': 0.701, 'Key': 0.112, 'Loudness': 6, 'Acousticness': 0.407, 'Instrumentalness': 0, 'Liveness': 0.112, 'Valence': 0.505, 'Tempo': 98.005, 'Track Reference': 'https://api.spotify.com/v1/tracks/7Bk0uXKk1uPT0XuQbpFzvs', '_id': ObjectId('60f790bfe1cf639cfad8a766')}
# {'Artist Name': 'Rauw Alejandro', 'Track Name': '2/Catorce', 'Danceability': 0.768, 'Energy': 0.56, 'Key': 0.115, 'Loudness': 3, 'Acousticness': 0.709, 'Instrumentalness': 0.000791, 'Liveness': 0.115, 'Valence': 0.372, 'Tempo': 112.084, 'Track Reference': 'https://api.spotify.com/v1/tracks/0PwFN7vRvY80Hnkoew2x3f', '_id': ObjectId('60f790bfe1cf639cfad8a767')}
# {'Artist Name': 'LAGOS', 'Track Name': 'Mónaco', 'Danceability': 0.699, 'Energy': 0.654, 'Key': 0.095, 'Loudness': 11, 'Acousticness': 0.054, 'Instrumentalness': 7.08e-06, 'Liveness': 0.095, 'Valence': 0.319, 'Tempo': 100.037, 'Track Reference': 'https://api.spotify.com/v1/tracks/3HgvO4B5LLmdPOT2d8cSZd', '_id': ObjectId('60f790bfe1cf639cfad8a768')}
# {'Artist Name': 'J Balvin', 'Track Name': 'Poblado - Remix', 'Danceability': 0.813, 'Energy': 0.809, 'Key': 0.377, 'Loudness': 3, 'Acousticness': 0.102, 'Instrumentalness': 1.37e-06, 'Liveness': 0.377, 'Valence': 0.646, 'Tempo': 93.005, 'Track Reference': 'https://api.spotify.com/v1/tracks/1WedZeiezCmCEOzLwhx0hV', '_id': ObjectId('60f790bfe1cf639cfad8a769')}
# {'Artist Name': 'Marca MP', 'Track Name': 'Ya Acabo', 'Danceability': 0.673, 'Energy': 0.326, 'Key': 0.103, 'Loudness': 0, 'Acousticness': 0.696, 'Instrumentalness': 3.73e-06, 'Liveness': 0.103, 'Valence': 0.672, 'Tempo': 133.309, 'Track Reference': 'https://api.spotify.com/v1/tracks/4H3t8C59tXjKf1R2iKtc5M', '_id': ObjectId('60f790bfe1cf639cfad8a76a')}
# {'Artist Name': 'Maluma', 'Track Name': 'Sobrio', 'Danceability': 0.762, 'Energy': 0.77, 'Key': 0.15, 'Loudness': 5, 'Acousticness': 0.138, 'Instrumentalness': 0, 'Liveness': 0.15, 'Valence': 0.631, 'Tempo': 177.998, 'Track Reference': 'https://api.spotify.com/v1/tracks/4HzqWEdAbzcVFDv0pvxV4w', '_id': ObjectId('60f790c0e1cf639cfad8a76b')}
# {'Artist Name': 'Wisin', 'Track Name': 'Fiel - Remix', 'Danceability': 0.839, 'Energy': 0.711, 'Key': 0.118, 'Loudness': 6, 'Acousticness': 0.398, 'Instrumentalness': 2.02e-06, 'Liveness': 0.118, 'Valence': 0.573, 'Tempo': 97.99, 'Track Reference': 'https://api.spotify.com/v1/tracks/43qcs9NpJhDxtG91zxFkj7', '_id': ObjectId('60f790c0e1cf639cfad8a76c')}
# {'Artist Name': 'KAROL G', 'Track Name': 'EL MAKINON', 'Danceability': 0.635, 'Energy': 0.706, 'Key': 0.108, 'Loudness': 5, 'Acousticness': 0.256, 'Instrumentalness': 0, 'Liveness': 0.108, 'Valence': 0.443, 'Tempo': 88.863, 'Track Reference': 'https://api.spotify.com/v1/tracks/2FSGUA0gFgGeQdprjtGM2M', '_id': ObjectId('60f790c0e1cf639cfad8a76d')}
# {'Artist Name': 'Natanael Cano', 'Track Name': 'Porte Exuberante', 'Danceability': 0.685, 'Energy': 0.831, 'Key': 0.177, 'Loudness': 4, 'Acousticness': 0.398, 'Instrumentalness': 0, 'Liveness': 0.177, 'Valence': 0.486, 'Tempo': 97.431, 'Track Reference': 'https://api.spotify.com/v1/tracks/4DdnffqoFr9wDRlCACNmGf', '_id': ObjectId('60f790c0e1cf639cfad8a76e')}
# {'Artist Name': 'Maluma', 'Track Name': 'Hawái', 'Danceability': 0.783, 'Energy': 0.727, 'Key': 0.0626, 'Loudness': 6, 'Acousticness': 0.185, 'Instrumentalness': 2.46e-05, 'Liveness': 0.0626, 'Valence': 0.558, 'Tempo': 180.067, 'Track Reference': 'https://api.spotify.com/v1/tracks/1yoMvmasuxZfqHEipJhRbp', '_id': ObjectId('60f790c0e1cf639cfad8a76f')}
# {'Artist Name': 'Kali Uchis', 'Track Name': 'telepatía', 'Danceability': 0.653, 'Energy': 0.524, 'Key': 0.203, 'Loudness': 11, 'Acousticness': 0.112, 'Instrumentalness': 0, 'Liveness': 0.203, 'Valence': 0.553, 'Tempo': 83.97, 'Track Reference': 'https://api.spotify.com/v1/tracks/6tDDoYIxWvMLTdKpjFkc1B', '_id': ObjectId('60f790c1e1cf639cfad8a770')}
# {'Artist Name': 'Ingratax', 'Track Name': 'París', 'Danceability': 0.57, 'Energy': 0.455, 'Key': 0.0654, 'Loudness': 1, 'Acousticness': 0.441, 'Instrumentalness': 0.000746, 'Liveness': 0.0654, 'Valence': 0.399, 'Tempo': 167.933, 'Track Reference': 'https://api.spotify.com/v1/tracks/4bF2y8rR7GUjrd5LNEvej3', '_id': ObjectId('60f790c1e1cf639cfad8a771')}
# {'Artist Name': 'Sech', 'Track Name': 'Sal y Perrea', 'Danceability': 0.786, 'Energy': 0.899, 'Key': 0.299, 'Loudness': 10, 'Acousticness': 0.192, 'Instrumentalness': 0.000189, 'Liveness': 0.299, 'Valence': 0.813, 'Tempo': 90.025, 'Track Reference': 'https://api.spotify.com/v1/tracks/5u7twkeask1VIyDeNTElSU', '_id': ObjectId('60f790c1e1cf639cfad8a772')}
# {'Artist Name': 'Doja Cat', 'Track Name': 'Kiss Me More (feat. SZA)', 'Danceability': 0.764, 'Energy': 0.705, 'Key': 0.12, 'Loudness': 8, 'Acousticness': 0.259, 'Instrumentalness': 8.92e-05, 'Liveness': 0.12, 'Valence': 0.781, 'Tempo': 110.97, 'Track Reference': 'https://api.spotify.com/v1/tracks/3DarAbFujv6eYNliUTyqtz', '_id': ObjectId('60f790c1e1cf639cfad8a773')}
# {'Artist Name': 'Mora', 'Track Name': '512', 'Danceability': 0.818, 'Energy': 0.673, 'Key': 0.172, 'Loudness': 4, 'Acousticness': 0.348, 'Instrumentalness': 0, 'Liveness': 0.172, 'Valence': 0.695, 'Tempo': 87.961, 'Track Reference': 'https://api.spotify.com/v1/tracks/5jzEwSyyymBlf1fa1o39T2', '_id': ObjectId('60f790c1e1cf639cfad8a774')}
# {'Artist Name': 'Myke Towers', 'Track Name': 'Bandido', 'Danceability': 0.713, 'Energy': 0.617, 'Key': 0.0962, 'Loudness': 8, 'Acousticness': 0.122, 'Instrumentalness': 0, 'Liveness': 0.0962, 'Valence': 0.682, 'Tempo': 168.021, 'Track Reference': 'https://api.spotify.com/v1/tracks/1xK1Gg9SxG8fy2Ya373oqb', '_id': ObjectId('60f790c2e1cf639cfad8a775')}
# {'Artist Name': 'TINI', 'Track Name': 'Miénteme', 'Danceability': 0.85, 'Energy': 0.541, 'Key': 0.286, 'Loudness': 2, 'Acousticness': 0.161, 'Instrumentalness': 5.01e-06, 'Liveness': 0.286, 'Valence': 0.916, 'Tempo': 92.003, 'Track Reference': 'https://api.spotify.com/v1/tracks/0cOa970mzTWAxKtltpkpLc', '_id': ObjectId('60f790c2e1cf639cfad8a776')}
# {'Artist Name': 'Olivia Rodrigo', 'Track Name': 'good 4 u', 'Danceability': 0.563, 'Energy': 0.664, 'Key': 0.0849, 'Loudness': 9, 'Acousticness': 0.335, 'Instrumentalness': 0, 'Liveness': 0.0849, 'Valence': 0.688, 'Tempo': 166.928, 'Track Reference': 'https://api.spotify.com/v1/tracks/4ZtFanR9U6ndgddUvNcjcG', '_id': ObjectId('60f790c2e1cf639cfad8a777')}
# {'Artist Name': 'Bad Bunny', 'Track Name': 'LA NOCHE DE ANOCHE', 'Danceability': 0.856, 'Energy': 0.618, 'Key': 0.0866, 'Loudness': 7, 'Acousticness': 0.0303, 'Instrumentalness': 0, 'Liveness': 0.0866, 'Valence': 0.391, 'Tempo': 81.993, 'Track Reference': 'https://api.spotify.com/v1/tracks/2XIc1pqjXV3Cr2BQUGNBck', '_id': ObjectId('60f790c2e1cf639cfad8a778')}
# {'Artist Name': 'BTS', 'Track Name': 'Permission to Dance', 'Danceability': 0.702, 'Energy': 0.741, 'Key': 0.337, 'Loudness': 9, 'Acousticness': 0.00544, 'Instrumentalness': 0, 'Liveness': 0.337, 'Valence': 0.646, 'Tempo': 124.925, 'Track Reference': 'https://api.spotify.com/v1/tracks/0LThjFY2iTtNdd4wviwVV2', '_id': ObjectId('60f790c2e1cf639cfad8a779')}
# {'Artist Name': 'Grupo Firme', 'Track Name': 'El Tóxico', 'Danceability': 0.626, 'Energy': 0.503, 'Key': 0.234, 'Loudness': 10, 'Acousticness': 0.407, 'Instrumentalness': 0, 'Liveness': 0.234, 'Valence': 0.821, 'Tempo': 72.985, 'Track Reference': 'https://api.spotify.com/v1/tracks/7E9GeFGfjXw9LAI4ay6rsw', '_id': ObjectId('60f790c2e1cf639cfad8a77a')}
# {'Artist Name': 'Nio Garcia', 'Track Name': 'AM', 'Danceability': 0.83, 'Energy': 0.517, 'Key': 0.0916, 'Loudness': 6, 'Acousticness': 0.399, 'Instrumentalness': 8.95e-05, 'Liveness': 0.0916, 'Valence': 0.616, 'Tempo': 171.959, 'Track Reference': 'https://api.spotify.com/v1/tracks/2dNhNlpZAtV4lwAFW45LIv', '_id': ObjectId('60f790c3e1cf639cfad8a77b')}
# {'Artist Name': 'Natti Natasha', 'Track Name': 'Ram Pam Pam', 'Danceability': 0.908, 'Energy': 0.813, 'Key': 0.278, 'Loudness': 5, 'Acousticness': 0.305, 'Instrumentalness': 0, 'Liveness': 0.278, 'Valence': 0.924, 'Tempo': 97.018, 'Track Reference': 'https://api.spotify.com/v1/tracks/4DHDIdeayp8xvlyg22wREO', '_id': ObjectId('60f790c3e1cf639cfad8a77c')}
# {'Artist Name': 'Sech', 'Track Name': '911 - Remix', 'Danceability': 0.816, 'Energy': 0.71, 'Key': 0.292, 'Loudness': 7, 'Acousticness': 0.165, 'Instrumentalness': 0, 'Liveness': 0.292, 'Valence': 0.784, 'Tempo': 93.02, 'Track Reference': 'https://api.spotify.com/v1/tracks/27RSJHEA99Y0Vsow7nA37A', '_id': ObjectId('60f790c3e1cf639cfad8a77d')}
# {'Artist Name': 'Bad Bunny', 'Track Name': 'De Museo', 'Danceability': 0.592, 'Energy': 0.494, 'Key': 0.13, 'Loudness': 4, 'Acousticness': 0.237, 'Instrumentalness': 0, 'Liveness': 0.13, 'Valence': 0.231, 'Tempo': 132.037, 'Track Reference': 'https://api.spotify.com/v1/tracks/267NGliXM8YLVZiKAD9Otm', '_id': ObjectId('60f790c3e1cf639cfad8a77e')}
# {'Artist Name': 'J Balvin', 'Track Name': 'In Da Getto', 'Danceability': 0.915, 'Energy': 0.72, 'Key': 0.0942, 'Loudness': 8, 'Acousticness': 0.025, 'Instrumentalness': 1.42e-05, 'Liveness': 0.0942, 'Valence': 0.631, 'Tempo': 126.986, 'Track Reference': 'https://api.spotify.com/v1/tracks/63aj87TQG6F3RVO5nbG2VQ', '_id': ObjectId('60f790c3e1cf639cfad8a77f')}
# {'Artist Name': 'BTS', 'Track Name': 'Butter', 'Danceability': 0.759, 'Energy': 0.459, 'Key': 0.0906, 'Loudness': 8, 'Acousticness': 0.00323, 'Instrumentalness': 0, 'Liveness': 0.0906, 'Valence': 0.695, 'Tempo': 109.997, 'Track Reference': 'https://api.spotify.com/v1/tracks/2bgTY4UwhfBYhGT4HUYStN', '_id': ObjectId('60f790c4e1cf639cfad8a780')}
# {'Artist Name': 'Pablo Alborán', 'Track Name': 'Saturno', 'Danceability': 0.278, 'Energy': 0.572, 'Key': 0.063, 'Loudness': 7, 'Acousticness': 0.392, 'Instrumentalness': 0, 'Liveness': 0.063, 'Valence': 0.311, 'Tempo': 95.351, 'Track Reference': 'https://api.spotify.com/v1/tracks/2f0Ft2XdvNSMSY5TUlZgEz', '_id': ObjectId('60f790c4e1cf639cfad8a781')}
# {'Artist Name': 'Christian Nodal', 'Track Name': 'Aquí Abajo', 'Danceability': 0.638, 'Energy': 0.437, 'Key': 0.0894, 'Loudness': 4, 'Acousticness': 0.282, 'Instrumentalness': 0, 'Liveness': 0.0894, 'Valence': 0.618, 'Tempo': 147.88, 'Track Reference': 'https://api.spotify.com/v1/tracks/16ONd70tvWAaLIc6hcLzaG', '_id': ObjectId('60f790c4e1cf639cfad8a782')}
# {'Artist Name': 'KAROL G', 'Track Name': 'BICHOTA', 'Danceability': 0.864, 'Energy': 0.658, 'Key': 0.105, 'Loudness': 1, 'Acousticness': 0.204, 'Instrumentalness': 0.000626, 'Liveness': 0.105, 'Valence': 0.865, 'Tempo': 163.922, 'Track Reference': 'https://api.spotify.com/v1/tracks/1WvrDdouh6C51In1SdATbq', '_id': ObjectId('60f790c4e1cf639cfad8a783')}
# {'Artist Name': 'The Weeknd', 'Track Name': 'Save Your Tears (with Ariana Grande) (Remix)', 'Danceability': 0.65, 'Energy': 0.825, 'Key': 0.0936, 'Loudness': 0, 'Acousticness': 0.0215, 'Instrumentalness': 2.44e-05, 'Liveness': 0.0936, 'Valence': 0.593, 'Tempo': 118.091, 'Track Reference': 'https://api.spotify.com/v1/tracks/37BZB0z9T8Xu7U3e65qxFy', '_id': ObjectId('60f790c4e1cf639cfad8a784')}
# {'Artist Name': 'Bizarrap', 'Track Name': 'Nicky Jam: Bzrp Music Sessions, Vol. 41', 'Danceability': 0.627, 'Energy': 0.849, 'Key': 0.145, 'Loudness': 1, 'Acousticness': 0.0913, 'Instrumentalness': 0, 'Liveness': 0.145, 'Valence': 0.818, 'Tempo': 89.907, 'Track Reference': 'https://api.spotify.com/v1/tracks/03LfOYi0icz4souspZVVhq', '_id': ObjectId('60f790c5e1cf639cfad8a785')}
# {'Artist Name': 'Lenin Ramírez', 'Track Name': 'Yo Ya No Vuelvo Contigo - En Vivo', 'Danceability': 0.643, 'Energy': 0.35, 'Key': 0.102, 'Loudness': 4, 'Acousticness': 0.784, 'Instrumentalness': 0, 'Liveness': 0.102, 'Valence': 0.541, 'Tempo': 118.199, 'Track Reference': 'https://api.spotify.com/v1/tracks/1s59X35jDULAyOGmBuTAnd', '_id': ObjectId('60f790c5e1cf639cfad8a786')}
# {'Artist Name': 'El Fantasma', 'Track Name': 'Cabrón y Vago - En Vivo', 'Danceability': 0.547, 'Energy': 0.638, 'Key': 0.074, 'Loudness': 8, 'Acousticness': 0.697, 'Instrumentalness': 0, 'Liveness': 0.074, 'Valence': 0.876, 'Tempo': 176.277, 'Track Reference': 'https://api.spotify.com/v1/tracks/4nbWX2HzrOEnX4xxvYRCyU', '_id': ObjectId('60f790c5e1cf639cfad8a787')}
# {'Artist Name': 'Santa Fe Klan', 'Track Name': 'Debo Entender', 'Danceability': 0.678, 'Energy': 0.457, 'Key': 0.113, 'Loudness': 0, 'Acousticness': 0.741, 'Instrumentalness': 0, 'Liveness': 0.113, 'Valence': 0.563, 'Tempo': 72.156, 'Track Reference': 'https://api.spotify.com/v1/tracks/55mzJ0LftLnef8sxAjrMkU', '_id': ObjectId('60f790c5e1cf639cfad8a788')}
# {'Artist Name': 'Dua Lipa', 'Track Name': 'Levitating (feat. DaBaby)', 'Danceability': 0.702, 'Energy': 0.825, 'Key': 0.0674, 'Loudness': 6, 'Acousticness': 0.00883, 'Instrumentalness': 0, 'Liveness': 0.0674, 'Valence': 0.915, 'Tempo': 102.977, 'Track Reference': 'https://api.spotify.com/v1/tracks/5nujrmhLynf4yMoMtj8AQF', '_id': ObjectId('60f790c6e1cf639cfad8a789')}
# {'Artist Name': 'Rauw Alejandro', 'Track Name': 'Algo Mágico', 'Danceability': 0.699, 'Energy': 0.612, 'Key': 0.161, 'Loudness': 11, 'Acousticness': 0.757, 'Instrumentalness': 0, 'Liveness': 0.161, 'Valence': 0.591, 'Tempo': 100.005, 'Track Reference': 'https://api.spotify.com/v1/tracks/7D93pJcwymzaZx8WgBo2zG', '_id': ObjectId('60f790c6e1cf639cfad8a78a')}
# {'Artist Name': 'Ed Maverick', 'Track Name': 'Fuentes de Ortiz', 'Danceability': 0.83, 'Energy': 0.159, 'Key': 0.362, 'Loudness': 1, 'Acousticness': 0.946, 'Instrumentalness': 2.02e-05, 'Liveness': 0.362, 'Valence': 0.189, 'Tempo': 104.95, 'Track Reference': 'https://api.spotify.com/v1/tracks/0akyEssGRVHstqCSWXusJL', '_id': ObjectId('60f790c6e1cf639cfad8a78b')}
# {'Artist Name': 'Piso 21', 'Track Name': 'Tan Bonita', 'Danceability': 0.82, 'Energy': 0.804, 'Key': 0.064, 'Loudness': 9, 'Acousticness': 0.175, 'Instrumentalness': 0.00215, 'Liveness': 0.064, 'Valence': 0.844, 'Tempo': 110.982, 'Track Reference': 'https://api.spotify.com/v1/tracks/6mm3K0yWp6uzfOMuipM9Zh', '_id': ObjectId('60f790c6e1cf639cfad8a78c')}
# {'Artist Name': 'The Weeknd', 'Track Name': 'Blinding Lights', 'Danceability': 0.514, 'Energy': 0.73, 'Key': 0.0897, 'Loudness': 1, 'Acousticness': 0.00146, 'Instrumentalness': 9.54e-05, 'Liveness': 0.0897, 'Valence': 0.334, 'Tempo': 171.005, 'Track Reference': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b', '_id': ObjectId('60f790c6e1cf639cfad8a78d')}
# {'Artist Name': 'Banda MS de Sergio Lizárraga', 'Track Name': 'La Casita', 'Danceability': 0.832, 'Energy': 0.525, 'Key': 0.142, 'Loudness': 10, 'Acousticness': 0.277, 'Instrumentalness': 1.77e-05, 'Liveness': 0.142, 'Valence': 0.967, 'Tempo': 112.479, 'Track Reference': 'https://api.spotify.com/v1/tracks/0vtYnEw1eJwW26BrBnOAYJ', '_id': ObjectId('60f790c7e1cf639cfad8a78e')}
# {'Artist Name': 'Santa Fe Klan', 'Track Name': 'Todo Va a Estar Bien', 'Danceability': 0.611, 'Energy': 0.66, 'Key': 0.0636, 'Loudness': 4, 'Acousticness': 0.734, 'Instrumentalness': 0, 'Liveness': 0.0636, 'Valence': 0.582, 'Tempo': 137.668, 'Track Reference': 'https://api.spotify.com/v1/tracks/3XjRIN9vEt35lm1iStPcgq', '_id': ObjectId('60f790c7e1cf639cfad8a78f')}
# {'Artist Name': 'Lil Nas X', 'Track Name': 'MONTERO (Call Me By Your Name)', 'Danceability': 0.61, 'Energy': 0.508, 'Key': 0.384, 'Loudness': 8, 'Acousticness': 0.297, 'Instrumentalness': 0, 'Liveness': 0.384, 'Valence': 0.758, 'Tempo': 178.818, 'Track Reference': 'https://api.spotify.com/v1/tracks/67BtfxlNbhBmCDR2L2l8qd', '_id': ObjectId('60f790c7e1cf639cfad8a790')}
# {'Artist Name': 'J Balvin', 'Track Name': 'LA CANCIÓN', 'Danceability': 0.754, 'Energy': 0.646, 'Key': 0.108, 'Loudness': 7, 'Acousticness': 0.152, 'Instrumentalness': 1.85e-05, 'Liveness': 0.108, 'Valence': 0.429, 'Tempo': 176.089, 'Track Reference': 'https://api.spotify.com/v1/tracks/0fea68AdmYNygeTGI4RC18', '_id': ObjectId('60f790c7e1cf639cfad8a791')}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-b01dc1cb0970> in <module>
#      27     # print(response["audio_features"])
#      28
# ---> 29     danceability = response["audio_features"][0]["danceability"]
#      30     energy = response["audio_features"][0]["energy"]
#      31     key = response["audio_features"][0]["liveness"]
#
# KeyError: 'audio_features'
